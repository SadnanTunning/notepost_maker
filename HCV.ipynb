# %% [markdown]
# <a href="https://colab.research.google.com/github/SadnanTunning/notepost_maker/blob/main/HCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('HCV-Egy-Data.csv')
df
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0       56       1   35      2               1          1          1
# 1       46       1   29      1               2          2          1
# 2       57       1   33      2               2          2          2
# 3       49       2   33      1               2          1          2
# 4       59       1   32      1               1          2          1
# ...    ...     ...  ...    ...             ...        ...        ...
# 1380    44       1   29      1               2          2          2
# 1381    55       1   34      1               2          2          1
# 1382    42       1   26      2               2          1          1
# 1383    52       1   29      2               1          1          2
# 1384    55       2   26      1               2          2          2
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 0                                    2          2                 2  ...
# 1                                    2          2                 1  ...
# 2                                    1          1                 1  ...
# 3                                    1          2                 1  ...
# 4                                    2          2                 2  ...
# ...                                ...        ...               ...  ...
# 1380                                 1          1                 1  ...
# 1381                                 1          1                 1  ...
# 1382                                 1          2                 1  ...
# 1383                                 2          2                 1  ...
# 1384                                 1          2                 1  ...
#
#       ALT 36  ALT 48  ALT after 24 w  RNA Base   RNA 4   RNA 12  RNA EOT  \
# 0          5       5               5    655330  634536   288194        5
# 1         57     123              44     40620  538635   637056   336804
# 2          5       5               5    571148  661346        5   735945
# 3         48      77              33   1041941  449939   585688   744463
# 4         94      90              30    660410  738756  3731527   338946
# ...      ...     ...             ...       ...     ...      ...      ...
# 1380      63      44              45    387795   55938        5        5
# 1381      97      64              41    481378  152961   393339    73574
# 1382      87      39              24    612664  572756   806109   343719
# 1383      48      81              43    139872   76161   515730     2460
# 1384      64      71              34   1190577  628730        5        5
#
#       RNA EF  Baseline histological Grading  Baselinehistological staging
# 0          5                             13                             2
# 1      31085                              4                             2
# 2     558829                              4                             4
# 3     582301                             10                             3
# 4     242861                             11                             1
# ...      ...                            ...                           ...
# 1380       5                             15                             4
# 1381  236273                             10                             2
# 1382  160457                              6                             2
# 1383  696074                             15                             3
# 1384       5                             13                             3
#
# [1385 rows x 29 columns]

# %% [markdown]
# **DATA PREPARATION**

# %%
y = df['Baselinehistological staging']
y
# Out:
# 0       2
# 1       2
# 2       4
# 3       3
# 4       1
#        ..
# 1380    4
# 1381    2
# 1382    2
# 1383    3
# 1384    3
# Name: Baselinehistological staging, Length: 1385, dtype: int64

# %%
x = df.drop('Baselinehistological staging', axis=1)
x
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0       56       1   35      2               1          1          1
# 1       46       1   29      1               2          2          1
# 2       57       1   33      2               2          2          2
# 3       49       2   33      1               2          1          2
# 4       59       1   32      1               1          2          1
# ...    ...     ...  ...    ...             ...        ...        ...
# 1380    44       1   29      1               2          2          2
# 1381    55       1   34      1               2          2          1
# 1382    42       1   26      2               2          1          1
# 1383    52       1   29      2               1          1          2
# 1384    55       2   26      1               2          2          2
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 0                                    2          2                 2  ...
# 1                                    2          2                 1  ...
# 2                                    1          1                 1  ...
# 3                                    1          2                 1  ...
# 4                                    2          2                 2  ...
# ...                                ...        ...               ...  ...
# 1380                                 1          1                 1  ...
# 1381                                 1          1                 1  ...
# 1382                                 1          2                 1  ...
# 1383                                 2          2                 1  ...
# 1384                                 1          2                 1  ...
#
#       ALT 24  ALT 36  ALT 48  ALT after 24 w  RNA Base   RNA 4   RNA 12  \
# 0         81       5       5               5    655330  634536   288194
# 1        113      57     123              44     40620  538635   637056
# 2        116       5       5               5    571148  661346        5
# 3         88      48      77              33   1041941  449939   585688
# 4        120      94      90              30    660410  738756  3731527
# ...      ...     ...     ...             ...       ...     ...      ...
# 1380     127      63      44              45    387795   55938        5
# 1381     108      97      64              41    481378  152961   393339
# 1382     116      87      39              24    612664  572756   806109
# 1383      47      48      81              43    139872   76161   515730
# 1384     115      64      71              34   1190577  628730        5
#
#       RNA EOT  RNA EF  Baseline histological Grading
# 0           5       5                             13
# 1      336804   31085                              4
# 2      735945  558829                              4
# 3      744463  582301                             10
# 4      338946  242861                             11
# ...       ...     ...                            ...
# 1380        5       5                             15
# 1381    73574  236273                             10
# 1382   343719  160457                              6
# 1383     2460  696074                             15
# 1384        5       5                             13
#
# [1385 rows x 28 columns]

# %% [markdown]
# Data **Splliting**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2, random_state=100)

# %%
x_train
# Out:
#      Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 137    39       2   30      2               1          1          1
# 773    47       1   30      2               2          2          1
# 91     45       2   25      1               2          1          2
# 558    34       1   25      1               2          1          1
# 968    54       1   34      2               1          1          2
# ..    ...     ...  ...    ...             ...        ...        ...
# 802    37       1   33      1               2          2          1
# 53     59       1   32      2               1          1          1
# 350    59       1   23      2               2          2          2
# 79     38       1   34      1               2          1          2
# 792    38       1   34      1               2          1          1
#
#      Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 137                                 2          2                 2  ...
# 773                                 2          2                 2  ...
# 91                                  2          2                 2  ...
# 558                                 2          2                 2  ...
# 968                                 1          2                 1  ...
# ..                                ...        ...               ...  ...
# 802                                 1          2                 2  ...
# 53                                  1          2                 2  ...
# 350                                 2          2                 2  ...
# 79                                  1          1                 2  ...
# 792                                 1          1                 2  ...
#
#      ALT 24  ALT 36  ALT 48  ALT after 24 w  RNA Base    RNA 4  RNA 12  \
# 137      94      57      65              45    442128  1043126  510354
# 773     100     102     101              39   1110695   683078       5
# 91       72     128      79              32    488111   579154  372958
# 558     114     119      71              33    360670   740270  638816
# 968      49     106     122              31    264528   998129  121818
# ..      ...     ...     ...             ...       ...      ...     ...
# 802      46     105      77              35    865914   949294       5
# 53       44      89     125              32    253848   257913  382306
# 350      82      89      67              26    575211     5130  749330
# 79       67      43      68              40     54743   390760  197060
# 792      44      92     116              24    186900   352315   54512
#
#      RNA EOT  RNA EF  Baseline histological Grading
# 137   407437  187721                             14
# 773        5       5                              6
# 91    573360  437164                             15
# 558   344817  226880                              3
# 968   442555  726750                              9
# ..       ...     ...                            ...
# 802        5       5                              3
# 53    672711  385161                              5
# 350   435165  217873                             13
# 79    388410  332045                              8
# 792   292604  566042                             11
#
# [1108 rows x 28 columns]

# %%
x_test
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 330     44       1   34      2               2          2          2
# 921     32       1   31      1               1          1          1
# 969     41       1   32      2               2          2          2
# 434     51       2   27      1               1          2          2
# 799     32       1   31      1               1          1          2
# ...    ...     ...  ...    ...             ...        ...        ...
# 1276    39       2   22      2               1          2          2
# 715     33       2   23      1               2          2          2
# 864     61       1   24      2               1          1          1
# 1229    40       2   26      1               2          1          2
# 267     49       2   22      1               1          1          2
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 330                                  1          1                 2  ...
# 921                                  2          2                 2  ...
# 969                                  1          1                 2  ...
# 434                                  2          2                 2  ...
# 799                                  1          2                 2  ...
# ...                                ...        ...               ...  ...
# 1276                                 1          2                 2  ...
# 715                                  2          2                 2  ...
# 864                                  1          1                 1  ...
# 1229                                 1          2                 2  ...
# 267                                  1          1                 1  ...
#
#       ALT 24  ALT 36  ALT 48  ALT after 24 w  RNA Base    RNA 4  RNA 12  \
# 330       90      81      69              23    193487    37441  486078
# 921      106     128      76              34    364186   888527  492947
# 969       82      95      60              43    837024   471355  454301
# 434      115      87     110              40    886791  1130520       5
# 799      101      50      61              25    746958    80639  389790
# ...      ...     ...     ...             ...       ...      ...     ...
# 1276      85      63     114              44    780887  1066136  496045
# 715      125     114      63              38    515507   122014  145140
# 864      119      43      56              38    868193   883529  810028
# 1229      80     119      46              26    559273  1122661  443091
# 267      122     120      67              33    259977   474454  388460
#
#       RNA EOT  RNA EF  Baseline histological Grading
# 330     10648  335763                             13
# 921    352946  578238                             12
# 969    431075  533187                             15
# 434         5       5                             12
# 799    553386  191695                              3
# ...       ...     ...                            ...
# 1276   756611  206077                             12
# 715    414447  698735                              4
# 864     46314  748470                             16
# 1229   360077  339703                             12
# 267     67799  387088                             14
#
# [277 rows x 28 columns]

# %% [markdown]
# ```
#
# **MODEL BUILDING**

# %% [markdown]
# ### LINEAR REGRESSION

# %% [markdown]
# training the model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# applying the model to make a prediction

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
print(y_lr_train_pred)
# Out:
# [2.29541565 2.43907068 2.42133195 ... 2.63624602 2.50362124 2.37551057]

# %%
print(y_lr_test_pred)
# Out:
# [2.32901939 2.25293347 2.42154951 2.21554029 2.69838942 2.4191528
#  2.4991755  2.64030767 2.5258671  2.65406515 2.75000062 2.55003891
#  2.29159127 2.36360354 2.41542719 2.29220154 2.46085281 2.44351937
#  2.31875161 2.58469523 2.32700656 2.91082842 2.71071739 2.41714846
#  2.54696482 2.23657575 2.7003145  2.5418509  2.31024786 2.43253431
#  2.47339586 2.30870217 2.62049449 2.58682292 2.44700121 2.73053015
#  2.64436243 2.33369989 2.38025307 2.46068345 2.79153675 2.32923617
#  2.62839635 2.46509421 2.09027377 2.58183166 2.29094681 2.54621572
#  2.59043377 2.37442184 2.65024336 2.755329   2.70503208 2.5788821
#  2.38911475 2.35456001 2.19554997 2.43133758 2.66148221 2.47184249
#  2.28076577 2.70721924 2.42541818 2.602884   2.3437271  2.30537607
#  2.3101569  2.77052209 2.53418062 2.49824262 2.32427035 2.34716318
#  2.61888081 2.4021741  2.20806836 2.46697948 2.58824276 2.09143581
#  2.72344796 2.13776208 2.52901704 2.17491496 2.68746621 2.43245876
#  2.34959444 2.34040575 2.4240561  2.51473618 2.59368794 2.27910564
#  2.37931143 2.14430247 2.68283145 2.7235677  2.67036076 2.44693111
#  2.69548664 2.53336032 2.61177599 2.1391141  2.41329647 2.82532435
#  2.54317294 2.62424197 2.7272365  2.68357399 2.42967862 2.65572307
#  2.54618405 2.29316095 2.48365246 2.83613524 2.52537663 2.25352134
#  2.50075476 2.40062332 2.49287223 2.39253977 2.61037191 2.19218183
#  2.49020483 2.26031697 2.54492701 2.15046607 2.35624867 2.64229406
#  2.84130253 2.39941945 2.64906079 2.23640032 2.34508497 2.40675144
#  2.60591274 2.89354134 2.5120738  2.5118133  2.24862486 2.86539875
#  2.60113577 2.62389818 2.62236969 2.69481247 2.50738617 2.33290721
#  2.65527687 2.50528131 2.40630584 2.53509411 2.52683351 2.57830049
#  2.83515779 2.55466459 2.55127878 2.51014653 2.46552463 2.42591429
#  2.18489632 2.38227537 2.53816037 2.57648451 2.1065676  2.58753374
#  2.8471584  2.64249717 2.60086991 2.4162046  2.67057358 2.44065347
#  2.47623601 2.16241202 2.51540907 2.66199231 2.70017835 2.59062086
#  2.47970866 2.25676749 2.56321766 2.28971871 2.24256284 2.16006517
#  2.56711497 2.34073974 2.6036561  2.56413834 2.6866951  2.75417643
#  2.64705505 2.52685347 2.56473574 2.6823616  2.61051239 2.54296698
#  2.37418702 2.8952502  2.60315171 2.71726745 2.61289077 2.54839554
#  2.61670188 2.54187958 2.30253133 2.64925095 2.46882094 2.76134323
#  2.69758467 2.65397602 2.39058513 2.22636051 2.85337286 2.76429235
#  2.56493124 2.62699996 2.5163603  2.26378233 2.68283749 2.51686475
#  2.20374895 2.45084317 2.43448772 2.49016038 2.81577544 2.13914044
#  2.59917626 2.46466049 2.56809149 2.58365823 2.50211027 2.48452982
#  2.35425654 2.14618268 2.74841399 2.4432811  2.45552845 2.74836571
#  2.71008212 2.55938916 2.56079426 2.86519237 2.76441455 2.32934778
#  2.67489133 2.78355728 2.46427033 2.83254757 2.40790822 2.83026136
#  2.19043881 2.68715689 2.4457205  2.67904736 2.47934528 2.04803628
#  2.53870811 2.95265769 2.58214027 2.375992   2.63535505 2.55763608
#  2.34966788 2.68364053 3.06098577 2.31104173 2.70620505 2.80378028
#  2.50234706 2.35754234 2.59626992 2.48423535 2.76417063 2.3637936
#  2.55180485 2.75372618 2.65403733 2.90686131 2.57707237 2.63447154
#  2.47423516]

# %% [markdown]
# **Evaluate model performence**

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (TRAIN): ', lr_train_mse)
print('LR R2 (TRAIN):', lr_train_r2)
print('LR MSE (TEST): ', lr_test_mse)
print('LR R2 (TEST):', lr_test_r2)
# Out:
# LR MSE (TRAIN):  1.2247276224073336
# LR R2 (TRAIN): 0.02977236003342809
# LR MSE (TEST):  1.272307208062656
# LR R2 (TEST): -0.03688645531003232

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     1.224728    0.029772  1.272307 -0.036886

# %% [markdown]
# **Random Forest**

# %% [markdown]
# Training the model

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# Applying the model to make a prediction

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# Evaluate model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2  Test MSE   Test R2
# 0  Random forest     1.203591    0.046516  1.251284 -0.019753

# %% [markdown]
# Model comparison

# %%
df_models = pd.concat([lr_results, rf_results], axis=0)

# %%
df_models.reset_index(drop=True)
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     1.224728    0.029772  1.272307 -0.036886
# 1      Random forest     1.203591    0.046516  1.251284 -0.019753

# %% [markdown]
# Data visualization of prediction results

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x=y_train, y=y_lr_train_pred, c="#7CAE00" ,alpha=0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
# Out:
# Text(0.5, 0, 'Experimental LogS')
